')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a657f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6586')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6588')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a658a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a658b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a658c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a658d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6593')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6594')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6595')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6597')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a659d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a659e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65a0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65a1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65a2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65a8')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65aa')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65ab')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65af')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65b1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65b2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65b4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65b8')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65ba')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65c0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65c1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65c4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65c5')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65c6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65c7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65c9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65ca')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65cb')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65cc')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65ce')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65d0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65d1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65d5')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65da')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65dc')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65df')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65e4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65e6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65e7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65e9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65f0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a65fb')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6602')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6607')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6609')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a661a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a661d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a661f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6620')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6621')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6622')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6623')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6630')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6633')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6634')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6635')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6638')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a663d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6643')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6647')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a664b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a664c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a664d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6650')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6653')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6654')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6659')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a665b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a665c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6660')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6670')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6673')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a667d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6680')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a668a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a668b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a668e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6692')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6695')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6696')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a669b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a669c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a669f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66a0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66a3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66ac')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66b2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66c2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66c6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66cc')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66e0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66e1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66e2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66e6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66e7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a66ed')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a670b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a670f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6716')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6719')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a671a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a671b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a671e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6720')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6724')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6726')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6727')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6730')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6731')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6732')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6738')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a673b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6741')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6742')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6749')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a674e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a674f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6753')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6754')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6756')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a675b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6763')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6767')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6768')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a676d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a676e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6772')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6774')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6777')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a677c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a677d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a677f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6782')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6785')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6787')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6789')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a678a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6792')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6794')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6795')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6797')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a6799')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a679a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a679d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67a0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67a1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67a2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67a4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67a5')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67a6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67a8')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67a9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67aa')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67ab')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67ac')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67af')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67b0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67b3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67b4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67b6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67b9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67ba')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67bc')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67bd')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67bf')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67c3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67c6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67c7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67c9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67ca')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67cc')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67d6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222c58846685089a67db')}
# ...
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5d5')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5db')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5e1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5e3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5e6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5eb')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5f2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5f3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5f4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5f5')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5f8')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af5fb')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af606')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af607')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af608')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af611')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af615')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af616')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af617')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af626')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af628')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af62a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af62b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af62d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af62e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af62f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af630')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af637')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af640')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af643')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af647')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af64e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af656')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af659')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af65b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af65e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af65f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af660')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af662')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af663')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af664')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af665')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af668')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af669')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af674')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af67a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af67e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af67f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af681')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af685')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af688')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af689')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af68a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af68b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af68d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af68e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af690')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af697')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af69b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af69c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af69f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6a0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6a4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6a6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6a7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6ab')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6ac')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6af')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6b0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6b3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6b7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6ba')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6bd')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6c5')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6c9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6cd')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6d3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6d4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6d6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6dd')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6de')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6e0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6e8')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6e9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6ec')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6ee')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6f1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6f4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6f7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6f9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af6fc')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af701')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af702')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af703')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af705')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af709')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af70a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af70b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af70c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af70e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af711')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af715')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af71a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af71b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af71c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af721')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af72a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af72c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af72e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af732')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af733')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af734')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af735')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af736')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af737')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af739')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af73a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af73e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af73f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af741')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af742')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af745')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af746')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af747')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af748')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af74e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af753')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af756')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af757')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af758')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af75b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af75c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af75f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af760')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af765')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af76b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af76c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af770')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af775')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af77c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af77f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af784')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af785')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af78d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af78e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7b1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7b7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7c0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7c1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7c2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7c4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7c7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7c9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7cb')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7cc')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7cd')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7ce')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7cf')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7df')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7e4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7f0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7f1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7f6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af7f7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af802')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af804')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af808')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af80e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af80f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af812')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af813')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af815')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af81c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af82d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af832')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af83b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af83c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af844')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af846')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af84c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af84e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af854')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af858')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af859')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af85b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af861')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af869')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af86d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af86f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af870')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af873')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af874')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af875')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af877')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af878')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af87a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af87d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af87e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af87f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af883')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af884')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af885')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af888')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af889')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af88a')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af88b')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af88d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af88f')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af891')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af896')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af897')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af89d')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af89e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8a0')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8a1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8a8')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8ab')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8ad')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8b1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8bf')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8c1')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8c3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8c4')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8c8')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8c9')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8d7')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8e2')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8e3')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8ea')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8f6')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8fd')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af8ff')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af903')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af908')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af90c')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af90e')}
# {'BusinessTypeID': 1, '_id': ObjectId('6643222f58846685089af919')}
# {'BusinessTypeID': '', '_id': ObjectId('664715e76448c49590e3eb04')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({"BusinessName":"Penang Flavours"},
                          [ { "$set" : { "BusinessTypeID" : 1 } } ] )
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName':'Penang Flavours'}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664715e76448c49590e3eb04'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_restaurants = establishments.count_documents({"LocalAuthorityName":"Dover"})
print(f"There are {dover_restaurants} restaurants in the Dover Local Authority")
# Out:
# There are 994 restaurants in the Dover Local Authority

# %%
# Delete all documents where LocalAuthorityName is "Dover"
delete_dover_restaurants = establishments.delete_many({"LocalAuthorityName": "Dover"})

# %%
# Check if any remaining documents include Dover
dover_check = establishments.count_documents({"LocalAuthorityName":"Dover"})
print(f"There are {dover_check} restaurants in the Dover Local Authority")
# Out:
# There are 0 restaurants in the Dover Local Authority

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6643222c58846685089a60a2'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set':{'geocode.longitude' : {'$toDouble': '$geocode.longitude'}}} ])
establishments.update_many({}, [ {'$set':{'geocode.latitude' : {'$toDouble': '$geocode.latitude'}}} ])
# Out:
# UpdateResult({'n': 38787, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ {'$set':{'RatingValue' : {'$toDouble': '$RatingValue'}}} ])
# Out:
# UpdateResult({'n': 38787, 'nModified': 34696, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
query = {}
fields = {'geocode.longitude': 1, 'geocode.latitude': 1, 'RatingValue': 1}

results = establishments.find(query, fields)

for result in results:
    longitude = result.get('geocode', {}).get('longitude')
    latitude = result.get('geocode', {}).get('latitude')
    rating_value = result.get('RatingValue')
    
    print('Longitude type:', type(longitude))
    print('Latitude type:', type(latitude))
    print('RatingValue type:', type(rating_value))
# Out:
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# ...
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'NoneType'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type: <class 'float'>
# RatingValue type: <class 'float'>
# Longitude type: <class 'float'>
# Latitude type:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
